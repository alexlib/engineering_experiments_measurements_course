# %%
from scipy import signal

# %%
# Define transfer function
k = 1 		# sensitivity
wn = 546.72 # rad/s
z=0.467     # damping

sys = signal.lti(k*wn**2,[1,2*z*wn, wn**2])
plot(arange(1000)/wn,sys.step(N=1000)[1])
title('Step response')
xlabel('$t$ [sec]')
ylabel('E [V]')
# Out:
# /Library/Frameworks/Python.framework/Versions/7.3/lib/python2.7/site-packages/scipy/signal/ltisys.py:490: ComplexWarning: Casting complex values to real discards the imaginary part
#   GT = dot(dot(vti, diag(numpy.exp(dt * lam))), vt).astype(xout.dtype)
# /Library/Frameworks/Python.framework/Versions/7.3/lib/python2.7/site-packages/scipy/signal/ltisys.py:504: ComplexWarning: Casting complex values to real discards the imaginary part
#   vt).astype(xout.dtype)
